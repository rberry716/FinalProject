# %% [markdown]
# Data sets

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("fire.csv")

# %%
df["neighborhood"].value_counts().sort_index().plot.bar(y='neighborhood', 
                                                  subplots=False, 
                                                  figsize=(20,10 ))
# Out:
# <Axes: xlabel='neighborhood'>
